# %% [markdown]
# # TP01\-Deepnote Galvan Fernando

# %% [markdown]
# Actualmente soy un chofer de ambulancia,  con todo el entusiasmo de aprender ciencia de datos e ia para poder hacer un cambio en mi vida laboral ya sea en la empresa donde  estoy o realizar un cambio total del ambito de la salud\.

# %% [markdown]
# Las espectativas que tengo de esta materia son llevarme todo lo posible, como diria yo exprimir al maximo, un dominio solido en las herramientas que necesitare en el dia a dia si consigo este cambio que espero en mi vida\.

# %%
print("Mi primer notebook en deepnote")
# Out:
# Mi primer notebook en deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6d629f3a-1091-4a03-8fd9-01b63515eeec' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
